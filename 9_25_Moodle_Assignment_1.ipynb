# %% [markdown]
# Task 1:
#
# Over a week, I pinpointed my top 5 apps:
#
# YouTube: It offers a surprising wealth of niche educational content. Whether it's random recommendations or specific searches, YouTube has been both entertaining and enlightening.
#
# Reddit: For internet enthusiasts, Reddit is the ultimate hub. Whether you're seeking advice on programming or insights into high-level office jobs, you'll find a community here. Information sharing is its forte.
#
# Camera: I was surprised to discover how frequently I use it, considering the number of photos and slides I've encountered this month.
#
# Calculator: Another surprise. Looking back, it's clear why I use it extensively, though I didn't initially realize the time it saves.
#
# Google Docs: This is the real workhorse among my apps, with data showing me accessing it nearly 100 times a day during peak usage.

# %%
from pickle import NONE
#Task2:

#Item1 Input
print('What food item was purchased?:')
food = input()
print('What did the item cost (in $)?:')
food_cost = float(input())
print('How many were bought?')
food_quantity = float(input())

food_cost_total = food_quantity * food_cost
#Gratuity Calculation + Food Cost

food_tip = (food_cost_total * .15)
print(f'{food_tip:.2f}')
food_total = food_cost_total + food_tip

#Receipt
print('RECEIPT:')
print(food_quantity, food, 'costs a total of', food_cost_total)
print("")
print('15% tip/gratuity is:', f'{food_tip:.2f}')
print('Total with tip (in $):', f'{food_total:.2f}')
print("")

#Item2 Input
print('Enter a second item:')
print('What food item was purchased?:')
food2 = input()
print('What did the item cost (in $)?:')
food_cost2 = float(input())
print('How many were bought?')
food_quantity2 = float(input())

food_cost_total2 = food_quantity2 * food_cost2

#Gratuity Calculation + Food Cost
food_tip2 = (food_cost_total2 * .15)
food_total2 = food_cost_total2 + food_tip2

#Receipt
print('RECEIPT:')
print(food_quantity2, food2, 'costs a total of', food_cost_total2)
print("")
print('15% gratuity:', f'{food_tip2:.2f}')
print('Total with tip (in $):', f'{food_total2:.2f}')
# Out:
# What food item was purchased?:
# Water
# What did the item cost (in $)?:
# 1.25
# How many were bought?
# 2
# 0.38
# RECEIPT:
# 2.0 Water costs a total of 2.5
#
# 15% tip/gratuity is: 0.38
# Total with tip (in $): 2.88
#
# Enter a second item:
# What food item was purchased?:
# Large Popcorn
# What did the item cost (in $)?:
# 15
# How many were bought?
# 3
# RECEIPT:
# 3.0 Large Popcorn costs a total of 45.0
#
# 15% gratuity: 6.75
# Total with tip (in $): 51.75
